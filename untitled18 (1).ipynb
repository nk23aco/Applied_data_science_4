# %% [markdown]
# *   Student Name: Nithish Reddy Kurapati
# *   Registration NUmber : 23005994

# %%
# Loading neccessary packages
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %%
#  Reading the csv file
data=pd.read_csv("/content/churn2.csv")
# Viewing the top5 rows of the csv file
data.head(5)
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
# Number of rows and columns.
data.shape
# Out:
# (10000, 14)

# %%
# checking sum of null values
data.isna().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
# Count occurrences of each gender
gender_counts = data['Gender'].value_counts()

# Calculate total number of entries
total_entries = len(data)

# Calculate percentage of males and females
male_percentage = (gender_counts['Male'] / total_entries) * 100
female_percentage = (gender_counts['Female'] / total_entries) * 100

print("Male percentage:", male_percentage)
print("Female percentage:", female_percentage)
# Out:
# Male percentage: 54.56999999999999
# Female percentage: 45.43

# %%
def plot_active_inactive_members(data):
    """
    Plot the number of people active and inactive based on gender (Male or Female).

    Arguments:
        data (DataFrame): 'Gender' and 'IsActiveMember' columns in a pandas DataFrame.

    Returns:
        None
    """
    is_active_member_male = 0
    is_active_member_female = 0
    inactive_member_male = 0
    inactive_member_female = 0

    for index, row in data.iterrows():
        # Handling unexpected values in 'Gender' or 'IsActiveMember' columns
        gender = row['Gender']
        is_active = row['IsActiveMember']
        if gender not in ['Male', 'Female']:
            raise ValueError(f"Unexpected value '{gender}' in 'Gender' column.")
        if is_active not in [0, 1]:
            raise ValueError(f"Unexpected value '{is_active}' in 'IsActiveMember' column.")

        if gender == 'Male' and is_active == 1:
            is_active_member_male += 1
        elif gender == 'Male' and is_active == 0:
            inactive_member_male += 1
        elif gender == 'Female' and is_active == 1:
            is_active_member_female += 1
        else:
            inactive_member_female += 1

    # Labels for the bar graph.
    labels = ['Active Male (1)', 'Active Female (1)', 'Inactive Male (0)', 'Inactive Female (0)']
    counts = [is_active_member_male, is_active_member_female, inactive_member_male, inactive_member_female]
    # Size of the graph 8 X 6.
    plt.figure(figsize=(8, 6))
    # Plotting the bar graph and passing the parameters in function.
    bars = plt.bar(labels, counts, color=['blue', 'blue', 'pink', 'pink'])

    # Add annotations to each bar.
    for bar in bars:
        height = bar.get_height()
        plt.text(bar.get_x() + bar.get_width() / 2, height, height, ha='center', va='bottom')
    # Adding the labels and title for the graph.
    plt.xlabel('Gender and Activity', fontsize=14)
    plt.ylabel('Count', fontsize=14)
    plt.title('Counts of Active and Inactive Members by Gender', fontsize=14)
    plt.show()

# Calling the function.
plot_active_inactive_members(data)

# %%
def pie_chart(data):
    """
    Ploting  the share of males and females from the given DataFrame.

    Parameters:
        data: A pandas DataFrame containing a 'Gender' column with values 'Male' or 'Female'.

    """
    # Initialize counts for males and females
    male_count = 0
    female_count = 0

    # Iterate through each row in the DataFrame
    for index, row in data.iterrows():
        # checking the row with gender
        # and update the count
        gender = row['Gender']
        if gender == 'Male':
            male_count += 1
        elif gender == 'Female':
            female_count += 1
        else:
            # handling value error, if any exception occurs.
            raise ValueError(f"Unexpected value '{gender}' in 'Gender' column.")

    # Labels for a pie chart
    labels = ['Male', 'Female']
    # shares for the chart
    sizes = [male_count, female_count]
    # colors for the each share for the chart
    colors = ['blue', 'pink']
    # creating a pie chart with angle 140
    plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=140)
    # axis in equal.
    plt.axis('equal')
    # adding the title for the graph.
    plt.title('Distribution of Males and Females', fontsize=14)
    plt.show()

# Calling the function.
pie_chart(data)

# %%
def scatter_plot(data):
    """
    Plotting a scatter plot, age against NumOfProducts.

    Parameters:
        data (DataFrame): DataFrame containing the 'Age' and 'NumOfProducts' columns.

    Returns:
        None
    """
    # Plotting the scatter plot between age and number of products.
    plt.scatter(data['Age'], data['NumOfProducts'], alpha=0.7)

    # Adding x and ylabels and title for the scatter plot.
    plt.xlabel('Age', fontsize=14)
    plt.ylabel('NumOfProducts', fontsize=14)
    plt.title('Age vs. NumOfProducts', fontsize=14)

    # Display the plot.
    plt.show()

# Calling the function.
scatter_plot(data)

# %%
def violin_plot(data):
    """
    Plotting a 'Age' by 'Exited' to visualise in violin plot of these features..

    Parameters:
        data : A pandas DataFrame containing 'Age' and 'Exited' columns.

    """
    # Size of the plot 10 X 6.
    plt.figure(figsize=(10, 6))
    # Plotting the violin plot between age and exited.
    sns.violinplot(x='Exited', y='Age', data=data, palette='Set1', hue='Exited')
    # Adding the title and labels for the X and Y-axis.
    plt.title('Distribution of Age by Exited', fontsize=14)
    plt.xlabel('Exited', fontsize=14)
    plt.ylabel('Age', fontsize=14)
    # Adding the xticks for the X labels.
    plt.xticks(ticks=[0, 1], labels=['Not Exited', 'Exited'], fontsize=14)
    plt.show()

# Calling the function.
violin_plot(data)

# %%
def line_fitting(x, y):
    """
    Perform linear fitting and visualize the fitted line with confidence interval.

    Parameters:
        x : Independent variable (x-axis).
        y : Dependent variable (y-axis).

    Returns:
        tuple: Tuple containing slope, intercept, and confidence interval of the fitted line.
    """
    # Fitting a degree 1 using polyfit function.
    coefficients = np.polyfit(x, y, 1)

    # getting slope and y-intercept from the coefficients
    m, b = coefficients

    # Generate predicted y-values based on the line equation.
    y_pred = m * x + b

    # Calculating residuals
    residuals = y - y_pred

    # calculating the variance for the residuals
    variance = np.sum(residuals ** 2) / (len(x) - 2)

    # Calculating the standard error of the estimate
    std_error = np.sqrt(variance)

    # Calculate the t-value for a 95% confidence interval.
    t_value = 1.96

    # Calculating the confidence interval.
    confidence_interval = t_value * std_error

    # Plot the figure with size 10 X 6.
    plt.figure(figsize=(10, 6))
    # plotting the data points on the axis using scatter plot.
    plt.scatter(x, y, color='blue', label='Data points')
    # Fitting the best fit line on the data points.
    plt.plot(x, y_pred, color='red', label='Fitted line')

    # Plot error bars for the confidence interval
    plt.fill_between(x, y_pred - confidence_interval, y_pred + confidence_interval, color='gray', alpha=0.2)

    # Plot predictions with uncertainties
    predictions_x = [700, 750, 800]
    for pred_x in predictions_x:
        pred_y = m * pred_x + b
        plt.scatter(pred_x, pred_y, color='green', marker='o', label='Predicted points')

    #  Adding the X and Y labels for the plot.
    plt.xlabel('CreditScore', fontsize=14)
    plt.ylabel('Balance', fontsize=14)
    # add the titles for the plot.
    plt.title('Linear Fitting with Confidence Interval (CreditScore vs. Balance)', fontsize=14)
    plt.legend()
    # Adding the grid.
    plt.grid(True)
    plt.show()

    return m, b, confidence_interval

# Independent variable (x-axis)
x = data['CreditScore'].values
# Dependent variable (y-axis)
y = data['Balance'].values

# fitting the best fit line along with confidence interval 95%.
slope, intercept, confidence_interval = line_fitting(x, y)
# printing the slope.
print("Slope:", slope)
# printing the intercept.
print("Intercept:", intercept)
# printing the value at the confidence interval 95%.
print("Confidence Interval (95%):", confidence_interval)
# Out:
# Slope: 4.04673976751798
# Intercept: 73853.36852312429
# Confidence Interval (95%): 122302.62734727957

# %%
# global variable
scaler = StandardScaler()

def preprocess_data(data):
    """
    Standardizing the 'Age' and 'Balance' values in a columns .

    Parameters:
        data: DataFrame containing 'Age' and 'Balance' columns.

    Returns:
        ndarray: Standardized data.
    """
    return scaler.fit_transform(data[['Age', 'Balance']])

def perform_elbow_method(data_scaled):
    """
    calculating the optimal value using elbow method for clusters.

    Parameters:
        data_scaled: Standardized data.

    Returns:
        integer: Optimal number of clusters.
    """
    wcss = []
    for i in range(1, 11):
        kmeans = KMeans(n_clusters=i, random_state=0)
        kmeans.fit(data_scaled)
        wcss.append(kmeans.inertia_)
    plt.plot(range(1, 11), wcss, marker='o')
    plt.xlabel('Number of Clusters')
    plt.ylabel('WCSS')
    plt.title('Elbow Method')
    plt.grid(True)
    plt.show()
    return 4

def visualize_clusters(data_scaled, optimal_num_clusters):
    """
    Visualizing the clusters.

    Parameters:
        data_scaled (ndarray): Standardized data.
        optimal_num_clusters (int): Optimal number of clusters.
    """
    kmeans = KMeans(n_clusters=optimal_num_clusters, random_state=0)
    cluster_labels = kmeans.fit_predict(data_scaled)
    cluster_centers = kmeans.cluster_centers_

    plt.figure(figsize=(8, 6))
    for cluster_label in range(optimal_num_clusters):
        plt.scatter(data_scaled[cluster_labels == cluster_label, 0],
                    data_scaled[cluster_labels == cluster_label, 1],
                    label=f'Cluster {cluster_label + 1}')

    plt.scatter(cluster_centers[:, 0], cluster_centers[:, 1], marker='x', color='black', label='Cluster Centers')

    plt.xlabel('Standardized Age')
    plt.ylabel('Standardized Balance')
    plt.title('KMeans Clustering')
    plt.legend()
    plt.grid(True)
    plt.show()

def predict_new_data(X, kmeans):
    """
    Predicts cluster labels for new data points.

    Parameters:
        X (ndarray): New data points.
        kmeans (KMeans): Trained KMeans model.

    Returns:
        ndarray: Predicted cluster labels for new data points.
    """
    scaled_X = scaler.transform(X)
    return kmeans.predict(scaled_X)

# preprocessing the data
data_scaled = preprocess_data(data)

# calulating the optimal value for determing the clusters using elbow method.
optimal_num_clusters = perform_elbow_method(data_scaled)

# Performing KMeans clustering with the optimal number of clusters
kmeans = KMeans(n_clusters=optimal_num_clusters, random_state=0)
cluster_labels = kmeans.fit_predict(data_scaled)

# Visualizing the clusters
visualize_clusters(data_scaled, optimal_num_clusters)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
# sample data for prediction
X_new = np.array([[30, 50000], [40, 60000], [50, 70000], [90, 100000]])
predicted_labels = kmeans.predict(scaler.transform(X_new))
# Generate colors randomly based on the number of clusters
colors = plt.cm.viridis(np.linspace(0, 1, optimal_num_clusters))

# Plot the new data points with colors corresponding to their predicted clusters
for i, label in enumerate(predicted_labels):
    plt.scatter(X_new[i, 0], X_new[i, 1], color=colors[label], label=f'Predicted Cluster {label}')
plt.xlabel('Standardized Age', fontsize = 14)
plt.ylabel('Standardized Balance', fontsize = 14)
plt.title('KMeans Clustering', fontsize = 14)
plt.legend()
plt.grid(True)
plt.show()
# Predict cluster labels for new data points
predicted_labels = predict_new_data(X_new, kmeans)
print("Predicted labels for new data points:", predicted_labels)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Predicted labels for new data points: [1 1 0 3]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
# droppping the columns
data = data.drop(columns=[ 'HasCrCard', 'CustomerId', 'Exited', 'RowNumber'])
data.head(5)
# Out:
#     Surname  CreditScore Geography  Gender  Age  Tenure    Balance  \
# 0  Hargrave          619    France  Female   42       2       0.00
# 1      Hill          608     Spain  Female   41       1   83807.86
# 2      Onio          502    France  Female   42       8  159660.80
# 3      Boni          699    France  Female   39       1       0.00
# 4  Mitchell          850     Spain  Female   43       2  125510.82
#
#    NumOfProducts  IsActiveMember  EstimatedSalary
# 0              1               1        101348.88
# 1              1               1        112542.58
# 2              3               0        113931.57
# 3              2               0         93826.63
# 4              1               1         79084.10

# %%
# Generating descriptive statistics using describe function
description = data.describe()
# printing description
print(description)
# Out:
#         CreditScore           Age        Tenure        Balance  NumOfProducts  \
# count  10000.000000  10000.000000  10000.000000   10000.000000   10000.000000
# mean     650.528800     38.921800      5.012800   76485.889288       1.530200
# std       96.653299     10.487806      2.892174   62397.405202       0.581654
# min      350.000000     18.000000      0.000000       0.000000       1.000000
# 25%      584.000000     32.000000      3.000000       0.000000       1.000000
# 50%      652.000000     37.000000      5.000000   97198.540000       1.000000
# 75%      718.000000     44.000000      7.000000  127644.240000       2.000000
# max      850.000000     92.000000     10.000000  250898.090000       4.000000
#
#        IsActiveMember  EstimatedSalary
# count    10000.000000     10000.000000
# mean         0.515100    100090.239881
# std          0.499797     57510.492818
# min          0.000000        11.580000
# 25%          0.000000     51002.110000
# ...

# %%
# Calculating the correlation matrix for the dataframe confusion_matrix_1
confusion_matrix_1 = data.corr(numeric_only=True)
print(confusion_matrix_1)
# Out:
#                  CreditScore       Age    Tenure   Balance  NumOfProducts  \
# CreditScore         1.000000 -0.003965  0.000842  0.006268       0.012238
# Age                -0.003965  1.000000 -0.009997  0.028308      -0.030680
# Tenure              0.000842 -0.009997  1.000000 -0.012254       0.013444
# Balance             0.006268  0.028308 -0.012254  1.000000      -0.304180
# NumOfProducts       0.012238 -0.030680  0.013444 -0.304180       1.000000
# IsActiveMember      0.025651  0.085472 -0.028362 -0.010084       0.009612
# EstimatedSalary    -0.001384 -0.007201  0.007784  0.012797       0.014204
#
#                  IsActiveMember  EstimatedSalary
# CreditScore            0.025651        -0.001384
# Age                    0.085472        -0.007201
# Tenure                -0.028362         0.007784
# Balance               -0.010084         0.012797
# NumOfProducts          0.009612         0.014204
# IsActiveMember         1.000000        -0.011421
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

def plot_heatmap(confusion_matrix_1, title='Heatmap of Correlation matrix'):
    """
    Plotting a heatmap of the confusion matrix.

    Parameters:
        confusion_matrix (array-like): Confusion matrix data.
        title (str, optional): Title of the plot. Defaults to 'Heatmap of Correlation matrix'.

    """
    plt.figure(figsize=(8, 4))
    sns.heatmap(confusion_matrix_1, annot=True, cmap='summer', linewidths=0.5, fmt='.2g', linecolor='white')
    plt.title(title, fontsize = 14)
    plt.xticks(fontsize = 14)
    plt.yticks(fontsize = 14)
    plt.show()
plot_heatmap(confusion_matrix_1, title='Heatmap of Confusion Matrix')

# %%
def mean_for_columns():

  """
    Calculating mean of the columns, using loop.
    Mean(): pre-defined module, imported from Statistics library.

  """
  for i in all_columns:
    mean_value = data[i].mean()
    print("Mean of", i, ":", mean_value)

all_columns = ['CreditScore', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'IsActiveMember', 'EstimatedSalary']
mean_for_columns()
# Out:
# Mean of CreditScore : 650.5288
# Mean of Age : 38.9218
# Mean of Tenure : 5.0128
# Mean of Balance : 76485.889288
# Mean of NumOfProducts : 1.5302
# Mean of IsActiveMember : 0.5151
# Mean of EstimatedSalary : 100090.239881

# %%
def median_for_columns():

  """
    Calculating median of the columns, using loop.
    median(): pre-defined module, imported from Statistics library.

  """
  for i in all_columns:
    median_value = data[i].median()
    print("median of", i, ":", median_value)

all_columns = ['CreditScore', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'IsActiveMember', 'EstimatedSalary']
median_for_columns()
# Out:
# median of CreditScore : 652.0
# median of Age : 37.0
# median of Tenure : 5.0
# median of Balance : 97198.54000000001
# median of NumOfProducts : 1.0
# median of IsActiveMember : 1.0
# median of EstimatedSalary : 100193.915

# %%
def standard_deviation_for_columns():

  """
    Calculating standard deviation of the columns, using loop.
    standard_deviation(): pre-defined module, imported from Statistics library.

  """
  for i in all_columns:
    standard_deviation_value = data[i].std()
    print("Standard Deviation of", i, ":", standard_deviation_value)

all_columns = ['CreditScore', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'IsActiveMember', 'EstimatedSalary']
standard_deviation_for_columns()
# Out:
# Standard Deviation of CreditScore : 96.65329873613035
# Standard Deviation of Age : 10.487806451704609
# Standard Deviation of Tenure : 2.8921743770496837
# Standard Deviation of Balance : 62397.405202385955
# Standard Deviation of NumOfProducts : 0.5816543579989906
# Standard Deviation of IsActiveMember : 0.49979692845891893
# Standard Deviation of EstimatedSalary : 57510.49281769816

# %%
def skewness_for_columns():

  """
    Calculating skewness of the columns, using loop.
    skew(): pre-defined module, imported from Statistics library.

  """
  for i in all_columns:
    skewness_value = data[i].skew()
    print("skewness of", i, ":", skewness_value)

all_columns = ['CreditScore', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'IsActiveMember', 'EstimatedSalary']
skewness_for_columns()
# Out:
# skewness of CreditScore : -0.07160660820092675
# skewness of Age : 1.0113202630234552
# skewness of Tenure : 0.01099145797717904
# skewness of Balance : -0.14110871094154384
# skewness of NumOfProducts : 0.7455678882823168
# skewness of IsActiveMember : -0.06043662833499078
# skewness of EstimatedSalary : 0.0020853576615585162

# %%
def kurtosis_for_columns():

  """
    Calculating kurtosis of the columns, using loop.
    kurtosis(): pre-defined module, imported from Statistics library.

  """
  for i in all_columns:
    kurtosis_value = data[i].kurtosis()
    print("kurtosis of", i, ":", kurtosis_value)

all_columns = ['CreditScore', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'IsActiveMember', 'EstimatedSalary']
kurtosis_for_columns()
# Out:
# kurtosis of CreditScore : -0.42572568480291295
# kurtosis of Age : 1.3953470615086956
# kurtosis of Tenure : -1.1652252274891766
# kurtosis of Balance : -1.489411767941925
# kurtosis of NumOfProducts : 0.5829807629457178
# kurtosis of IsActiveMember : -1.9967468033281526
# kurtosis of EstimatedSalary : -1.1815184473915485
